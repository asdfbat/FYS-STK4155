# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
hp_df = pd.read_pickle("../data/hp_df.pickle")

# %%
plt.figure(figsize=(16,8))
plt.plot(hp_df["acc_score"])
plt.scatter(range(len(hp_df)), hp_df["accepted"])

# %%
hp_df
# Out:
#    accepted  acc_score        lr  batch_size  nr_Conv1  nr_Conv2  Conv_size  \
# 0         1   0.000000  0.001000        1024         2         2         32
# 1         1   0.895238  0.001000        1024         2         1         39
# 2         1   0.923810  0.001386        1024         3         1         39
# 3         0   0.795238  0.001386        1051         3         1         39
#
#    nr_flat  flat_size       reg   dropout
# 0        2        256  0.010000  0.250000
# 1        2        256  0.015246  0.250000
# 2        2        256  0.015246  0.250000
# 3        2        256  0.015246  0.227341

# %%
temp = np.random.uniform(0, 1, (10, 10000)) < 0.3
temp = np.sum(temp, axis=0)

plt.figure(figsize=(18,8))
plt.hist(temp, bins="auto");
